# %%
    def threeSum(num):
        re = []
        num.sort()
        n = len(num)
        if n < 3:
            return re
        i = 0
        while i < n-2:
            j = i + 1
            k = n - 1
            while j < k:
                if num[i] + num[j] + num[k] == 0:
                    re.append([num[i], num[j], num[k]])
                    tj = num[j]
                    tk = num[k]
                    for j in range(j+1, n):
                        if num[j] != tj:
                            break
                    for k in range(k-1, i, -1):
                        if num[k] != tk:
                            break
                elif num[i] + num[j] + num[k] < 0:
                    tj = num[j]
                    for j in range(j+1, n):
                        if num[j] != tj:
                            break
                else:
                    tk = num[k]
                    for k in range(k-1, i, -1):
                        if num[k] != tk:
                            break
            ti = num[i]
            while i < n and ti == num[i]:
                i += 1
        return re
    threeSum([7,-1,14,-12,-8,7,2,-15,8,8,-8,-14,-4,-5,7,9,11,-4,-15,-6,1,-14,4,3,10,-5,2,1,6,11,2,-2,-5,-7,-6,2,-15,11,-6,8,-4,2,1,-1,4,-6,-15,1,5,-15,10,14,9,-8,-6,4,-6,11,12,-15,7,-1,-9,9,-1,0,-4,-1,-12,-2,14,-9,7,0,-3,-4,1,-2,12,14,-10,0,5,14,-1,14,3,8,10,-8,8,-5,-2,6,-11,12,13,-7,-12,8,6,-13,14,-2,-5,-11,1,3,-6]
)
# Out:
# [[-15, 1, 14],
#  [-15, 2, 13],
#  [-15, 3, 12],
#  [-15, 4, 11],
#  [-15, 5, 10],
#  [-15, 6, 9],
#  [-15, 7, 8],
#  [-14, 0, 14],
#  [-14, 1, 13],
#  [-14, 2, 12],
#  [-14, 3, 11],
#  [-14, 4, 10],
#  [-14, 5, 9],
#  [-14, 6, 8],
#  [-14, 7, 7],
#  [-13, -1, 14],
#  [-13, 0, 13],
#  [-13, 1, 12],
#  [-13, 2, 11],
#  [-13, 3, 10],
#  [-13, 4, 9],
#  [-13, 5, 8],
#  [-13, 6, 7],
#  [-12, -2, 14],
#  [-12, -1, 13],
#  [-12, 0, 12],
#  [-12, 1, 11],
#  [-12, 2, 10],
#  [-12, 3, 9],
#  [-12, 4, 8],
#  [-12, 5, 7],
#  [-12, 6, 6],
#  [-11, -3, 14],
#  [-11, -2, 13],
#  [-11, -1, 12],
#  [-11, 0, 11],
#  [-11, 1, 10],
#  [-11, 2, 9],
#  [-11, 3, 8],
#  [-11, 4, 7],
#  [-11, 5, 6],
#  [-10, -4, 14],
#  [-10, -3, 13],
#  [-10, -2, 12],
#  [-10, -1, 11],
#  [-10, 0, 10],
#  [-10, 1, 9],
#  [-10, 2, 8],
#  [-10, 3, 7],
#  [-10, 4, 6],
#  [-10, 5, 5],
#  [-9, -5, 14],
#  [-9, -4, 13],
#  [-9, -3, 12],
#  [-9, -2, 11],
#  [-9, -1, 10],
#  [-9, 0, 9],
#  [-9, 1, 8],
#  [-9, 2, 7],
# ...
